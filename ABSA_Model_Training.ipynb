# %% [markdown]
# <a href="https://colab.research.google.com/github/Harjandar/absa-restaurant-sentiment/blob/main/ABSA_Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Harjandar/absa-restaurant-sentiment/main/data/raw/restaurants_train_single.csv"

df = pd.read_csv(url)
df.head()
# Out:
#   sentence Id                                           sentence  \
# 0   1004293:0  Judging from previous posts this used to be a ...
# 1   1004293:1  We, there were four of us, arrived at noon - t...
# 2   1004293:2  They never brought us complimentary noodles, i...
# 3   1004293:3  The food was lousy - too sweet or too salty an...
# 4   1004293:3  The food was lousy - too sweet or too salty an...
#
#       aspect_category aspect_term  from  to  polarity
# 0  RESTAURANT#GENERAL       place    51  56  negative
# 1     SERVICE#GENERAL       staff    75  80  negative
# 2     SERVICE#GENERAL         NaN     0   0  negative
# 3        FOOD#QUALITY        food     4   8  negative
# 4  FOOD#STYLE_OPTIONS    portions    52  60  negative
